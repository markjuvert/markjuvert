# %%
#Import my dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout
import os
import tensorflow as tf

# Print the head of the dataset to have an idea of the data
df = pd.read_csv('///Users/markjuvert/Desktop/RNN/Limestone.csv')
df.head()
# Out:
# Using TensorFlow backend.
# /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
#      Date  Open  High   Low  Close  Adj Close  Volume
# 0  1/2/14  5.00   5.0  4.70   4.70       4.70    7200
# 1  1/3/14  4.85   5.0  4.65   4.75       4.75    6400
# 2  1/6/14  4.60   5.0  4.60   4.85       4.85    7000
# 3  1/7/14  4.95   5.1  4.95   5.10       5.10    3600
# 4  1/8/14  5.10   5.3  4.95   5.05       5.05    8800

# %%
#preprocessing our data
df = df['Open'].values
df = df.reshape(-1,1)
print(df.shape)
df[:7]
# Out:
# (1575, 1)
# array([[5.  ],
#        [4.85],
#        [4.6 ],
#        [4.95],
#        [5.1 ],
#        [5.45],
#        [5.25]])

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8)-50:])
print(dataset_train.shape)
print(dataset_test.shape)

scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_train[:7]

dataset_test = scaler.transform(dataset_test)
dataset_test[:7]
# Out:
# (1260, 1)
# (365, 1)
# array([[0.88355263],
#        [0.87105263],
#        [0.87828947],
#        [0.86513158],
#        [0.85197368],
#        [0.83289474],
#        [0.82565789]])

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8)-50:])
print(dataset_train.shape)
print(dataset_test.shape)

scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_train[:7]

dataset_test = scaler.transform(dataset_test)
dataset_test[:7]

def create_my_dataset(df):
    x = []
    y = []
    for i in range(50,df.shape[0]):
        x.append(df[i-50:i,0])
        y.append(df[i,0])
    x = np.array(x)
    y = np.array(y)
    return x,y

x_train, y_train = create_my_dataset(dataset_train)
x_train[:1]

y_train[:1]

x_test, y_test = create_my_dataset(dataset_test)
x_test[:1]
# Out:
# (1260, 1)
# (365, 1)
# array([[0.88355263, 0.87105263, 0.87828947, 0.86513158, 0.85197368,
#         0.83289474, 0.82565789, 0.82565789, 0.84210526, 0.82565789,
#         0.84934211, 0.82697368, 0.82565789, 0.82565789, 0.84605263,
#         0.83421053, 0.83486842, 0.82697368, 0.82697368, 0.81776316,
#         0.83552632, 0.83223684, 0.80263158, 0.79144737, 0.79407895,
#         0.80328947, 0.82565789, 0.82565789, 0.825     , 0.76973684,
#         0.77039474, 0.76973684, 0.76973684, 0.7875    , 0.82565789,
#         0.80921053, 0.78289474, 0.76315789, 0.75986842, 0.72697368,
#         0.68289474, 0.71052632, 0.70065789, 0.69868421, 0.70921053,
#         0.74078947, 0.73815789, 0.73026316, 0.75065789, 0.76184211]])

# %%
#visualizing the accuracy and loss of the model
def visualize_results(results):
        history = results.history
        plt.figure(figsize=(14,8))
        plt.plot(history['val_loss'])
        plt.plot(history['loss'])
        plt.legend(['val_loss','loss'])
        plt.title('loss')
        plt.xlabel('epochs')
        plt.ylabel('loss')
        plt.show

        plt.figure(figsize=(14,8))
        plt.plot(history['val_accuracy'])
        plt.plot(history['accuracy'])
        plt.legend(['val_accuracy','accuracy'])
        plt.title('accuracy')
        plt.xlabel('epochs')
        plt.ylabel('accuracy')
        plt.show

# %%
#reshaping for LSTM
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))
print(x_train.shape)
print(x_test.shape)

model = Sequential()
model.add(LSTM(30, activation = 'softsign', return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(30, activation = 'softsign', return_sequences=True))
model.add(LSTM(30, activation = 'softsign'))
model.add(Dense(units=1))

model.summary()
# Out:
# (1210, 50, 1)
# (315, 50, 1)
# WARNING:tensorflow:From /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50, 30)            3840
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50, 30)            7320
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 30)                7320
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer ='adam', metrics=['accuracy'])
res = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# WARNING:tensorflow:From /Users/markjuvert/opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1089 samples, validate on 121 samples
# Epoch 1/50
# 1089/1089 [==============================] - 4s 4ms/step - loss: 0.0649 - accuracy: 0.0018 - val_loss: 0.1003 - val_accuracy: 0.0083
# Epoch 2/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0067 - accuracy: 0.0018 - val_loss: 0.0108 - val_accuracy: 0.0083
# Epoch 3/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.0018 - val_loss: 0.0025 - val_accuracy: 0.0083
# Epoch 4/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 0.0018 - val_loss: 0.0027 - val_accuracy: 0.0083
# Epoch 5/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0022 - val_accuracy: 0.0083
# Epoch 6/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0077 - val_accuracy: 0.0083
# Epoch 7/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0083
# Epoch 8/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0024 - val_accuracy: 0.0083
# Epoch 9/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0022 - accuracy: 0.0018 - val_loss: 0.0071 - val_accuracy: 0.0083
# Epoch 10/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0055 - val_accuracy: 0.0083
# Epoch 11/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0083
# Epoch 12/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0021 - val_accuracy: 0.0083
# Epoch 13/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0083
# Epoch 14/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0030 - val_accuracy: 0.0083
# Epoch 15/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0083
# Epoch 16/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0045 - val_accuracy: 0.0083
# Epoch 17/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0025 - val_accuracy: 0.0083
# Epoch 18/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0083
# Epoch 19/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0083
# Epoch 20/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0083
# Epoch 21/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0083
# Epoch 22/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0050 - val_accuracy: 0.0083
# Epoch 23/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0046 - val_accuracy: 0.0083
# Epoch 24/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0083
# Epoch 25/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0012 - accuracy: 0.0018 - val_loss: 0.0037 - val_accuracy: 0.0083
# Epoch 26/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0014 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0083
# Epoch 27/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0012 - accuracy: 0.0018 - val_loss: 9.6126e-04 - val_accuracy: 0.0083
# Epoch 28/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0022 - val_accuracy: 0.0083
# Epoch 29/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0083
# Epoch 30/50
# 1089/1089 [==============================] - 3s 3ms/step - loss: 0.0012 - accuracy: 0.0018 - val_loss: 8.6541e-04 - val_accuracy: 0.0083
# Epoch 31/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 0.0018 - val_loss: 0.0023 - val_accuracy: 0.0083
# Epoch 32/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 0.0018 - val_loss: 9.9750e-04 - val_accuracy: 0.0083
# Epoch 33/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0012 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0083
# Epoch 34/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0083
# Epoch 35/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0012 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0083
# Epoch 36/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 0.0018 - val_loss: 0.0011 - val_accuracy: 0.0083
# Epoch 37/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0010 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0083
# Epoch 38/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 9.9670e-04 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0083
# Epoch 39/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 9.8492e-04 - accuracy: 0.0018 - val_loss: 6.5057e-04 - val_accuracy: 0.0083
# Epoch 40/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 0.0018 - val_loss: 7.6334e-04 - val_accuracy: 0.0083
# Epoch 41/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 9.0421e-04 - accuracy: 0.0018 - val_loss: 6.0677e-04 - val_accuracy: 0.0083
# Epoch 42/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 9.4285e-04 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0083
# Epoch 43/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 9.0845e-04 - accuracy: 0.0018 - val_loss: 7.5597e-04 - val_accuracy: 0.0083
# Epoch 44/50
# 1089/1089 [==============================] - 3s 2ms/step - loss: 8.8315e-04 - accuracy: 0.0018 - val_loss: 5.5791e-04 - val_accuracy: 0.0083
# Epoch 45/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 0.0018 - val_loss: 5.7366e-04 - val_accuracy: 0.0083
# Epoch 46/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 8.2950e-04 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0083
# Epoch 47/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 7.9826e-04 - accuracy: 0.0018 - val_loss: 5.2870e-04 - val_accuracy: 0.0083
# Epoch 48/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 7.9051e-04 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0083
# Epoch 49/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 8.0881e-04 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0083
# Epoch 50/50
# 1089/1089 [==============================] - 2s 2ms/step - loss: 8.4692e-04 - accuracy: 0.0018 - val_loss: 5.7732e-04 - val_accuracy: 0.0083

# %%
#visualizing our predictions
# %matplotlib inline
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

fig, ax = plt.subplots(figsize=(20,10))
plt.plot(df, color='red', label='original Price')
ax.plot(range(len(y_train)+50, len(y_train)+50+len(predictions)),predictions,color='blue', label='Predicted Price')
plt.legend()
print(range(len(y_train)+50, len(y_train)+50+len(predictions)))

y_test_scaled = scaler.inverse_transform(y_test.reshape(-2,1))

fig, ax = plt.subplots(figsize=(20,10))
ax.plot(y_test_scaled, color='red', label = 'True Price of testing set')
plt.plot(predictions, color = 'blue', label='Predicted')
plt.legend()
plt.title('Limestone Price Prediction')
plt.xlabel('Days')
plt.ylabel('Limestone Price')
plt.show()
# Out:
# range(1260, 1575)
